# %% [markdown]
# <h4 align="center" style="height:1123px;"><b>
#
#     LAPORAN PRAKTIKUM
#
#     ALGORITMA & PEMOGRAMAN
#
#     “TIPE DATA DAN VARIABEL”
#
#     Disusun Oleh :
#
#     Adib Khairi Muzakki E
#
#     2611531021
#
#     Dosen Pengampu:
#
#     Wahyudi.DR.. S.T.M.T
#
#     Asisten Praktikum:
#
#     Rifki Yuliandra
#
# <br>
#
#  <img src="image/logo_unand.png" width="200">
#
# <br>
#
#     FAKULTAS TEKNOLOGI INFORMASI
#
#     DEPARTEMEN INFORMATIKA
#
#     UNIVERSITAS ANDALAS
#
#     2026
#
# </b></h4>
# </div>

# %% [markdown]
# ---
# <div style="height:1123px;font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# <h2 align="center">KATA PENGANTAR</h2>
# Puji syukur penulis panjatkan kehadirat Tuhan Yang Maha Esa karena atas rahmat dan karunia-Nya, penulis dapat menyelesaikan laporan praktikum yang berjudul “Tipe Data dan Variabel” dengan baik. Laporan ini disusun sebagai dokumentasi dan refleksi atas praktikum mata kuliah Praktikum Algoritma Pemrograman. Praktikum ini membahas konsep dasar tipe data dan variabel dalam bahasa pemrograman Python. Tipe data digunakan untuk menentukan jenis nilai dalam program, seperti int, float, komplek, string, boolean, konstanta serta penggunaan input, sedangkan variabel digunakan untuk menyimpan suatu nilai.
# <br>
# <br>
#
# Melalui praktikum ini, penulis diharapkan dapat memahami berbagai jenis tipe data dan cara menggunakan variabel dalam Python serta mampu menerapkannya dalam pembuatan program sederhana. Pemahaman mengenai tipe data dan variabel merupakan dasar penting dalam pemrograman karena digunakan dalam proses penyimpanan dan pengolahan data. Penulis menyadari bahwa laporan ini masih memiliki kekurangan, sehingga kritik dan saran yang membangun sangat diharapkan untuk perbaikan di masa mendatang.
#
# <div align="right" style="margin-left:-30px;">
# Padang, 2026
# <br>
# <br>
# <br>
# <br>
# <br>
# Adib Khairi Muzakki E
# <br>
# 2611531021
# </div>
# </div>

# %% [markdown]
# ---
# <div style="height:1123px;font-family: 'Times New Roman', Times, serif;font-size: 18px;">
# <h1 align="center">BAB I<br>PENDAHULUAN</h1>
#
# ## 1.1 Latar Belakang
# Pemrograman merupakan salah satu kemampuan penting dalam bidang Informatika. Sebagai mahasiswa Informatika semester 1, pemahaman dasar pemrograman perlu dikuasai untuk menunjang pembelajaran selanjutnya. Salah satu konsep dasar yang perlu dipahami dalam bahasa pemrograman Python adalah tipe data dan variabel, karena keduanya digunakan dalam proses penyimpanan dan pengolahan data pada program.
#
# Dalam Python, terdapat berbagai tipe data seperti int, float, komplek, string, boolean, konstanta serta penggunaan input yang digunakan sesuai dengan jenis nilai yang akan diproses. Variabel digunakan untuk menyimpan atau mereferensikan nilai tersebut. Oleh karena itu, praktikum Tipe Data dan Variabel dilakukan untuk memberikan pemahaman dasar mengenai berbagai tipe data dan penggunaan variabel dalam bahasa pemrograman Python.
#
# ## 1.2 Tujuan
# 1. Memahami konsep dasar tipe data dalam bahasa pemrograman Python.
# 2. Memahami konsep dan penggunaan variabel dalam Python.
# 3. Mampu membedakan berbagai jenis tipe data seperti int, float, komplek, string, boolean, konstanta serta penggunaan input.
# 4. Mampu menggunakan tipe data dan variabel dalam pembuatan program sederhana.
# 5. Mampu menerapkan tipe data dan variabel untuk mengolah data dalam program Python.
#
# ## 1.3 Manfaat
# 1. Memberikan pengalaman kepada mahasiswa dalam menggunakan tipe data dan variabel pada Python.
# 2. Meningkatkan pemahaman mahasiswa mengenai berbagai jenis tipe data.
# 3. Membantu mahasiswa memahami cara menyimpan dan mengolah data menggunakan variabel.
# 4. Melatih mahasiswa dalam menerapkan tipe data dan variabel pada program sederhana.
# 5. Menjadi dasar bagi mahasiswa untuk mempelajari konsep pemrograman Python yang lebih lanjut.
# </div>

# %% [markdown]
# ---
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
# <h1 align="center">BAB II<br>PEMBAHASAN</h1>
#
# ## 2.1 Dasar Teori
#
# Praktikum Pengenalan Python, VS Code, dan Koneksi ke GitHub membahas dasar penggunaan bahasa pemrograman Python, Visual Studio Code sebagai code editor, serta GitHub sebagai media penyimpanan dan pengelolaan kode program.
#
# Praktikum Tipe Data dan Variabel membahas konsep dasar dalam bahasa pemrograman Python yang digunakan untuk menyimpan dan mengolah data. Tipe data menentukan jenis nilai yang digunakan dalam program, sedangkan variabel digunakan untuk menyimpan atau mereferensikan nilai tersebut.
#
# 1. Integer (int)<br>
# Integer merupakan tipe data yang digunakan untuk menyimpan bilangan bulat, seperti 10, 25, dan -5.
# 2. Float (float)<br>
# Float digunakan untuk menyimpan bilangan yang memiliki nilai desimal, seperti 3.14, 10.5, dan 0.75.
# 3. Complex (complex)<br>
# Complex merupakan tipe data yang digunakan untuk menyimpan bilangan kompleks yang memiliki bagian real dan imajiner. Contohnya adalah 3+2j.
# 4. String (str)<br>
# String merupakan tipe data yang digunakan untuk menyimpan teks atau kumpulan karakter. String ditulis menggunakan tanda kutip, contohnya "Python" dan "Informatika".
# 5. Boolean (bool)<br>
# Boolean merupakan tipe data yang memiliki dua nilai, yaitu True dan False. Tipe data ini biasanya digunakan untuk menyatakan kondisi benar atau salah.
# 6. Konstanta<br>
# Konstanta merupakan nilai yang secara konsep tidak dimaksudkan untuk diubah selama program berjalan. Python tidak memiliki sintaks khusus untuk membuat konstanta, tetapi penamaan dengan huruf kapital dapat digunakan sebagai tanda bahwa suatu variabel dianggap sebagai konstanta, contohnya PI = 3.14.
# 7. Variabel<br>
# Variabel digunakan sebagai tempat untuk menyimpan atau mereferensikan suatu nilai. Dalam Python, variabel dapat dibuat dengan memberikan nilai menggunakan operator =, misalnya nama = "Adib" atau umur = 18.
# 8. Input dan Output<br>
# Python menyediakan fungsi input() untuk menerima data dari pengguna dan print() untuk menampilkan data ke layar. Data dari input() secara default bertipe str, sehingga perlu dilakukan konversi apabila data tersebut akan digunakan sebagai bilangan.
# <br>
# <br>
# Dengan memahami tipe data dan variabel, mahasiswa dapat menentukan jenis data yang sesuai serta menggunakannya dalam proses pengolahan data pada program Python.
#
# ## 2.2 Kode Program
#
# ### 2.2.1 Program Numeric_2611531021
# </div>

# %%
#create a variable with integer value
a_1021 = 100
print("The type of variable having value",a_1021,"is",type(a_1021))

#create variable with float value
b_1021 = 10.2345
print("The type of variable having value",b_1021,"is",type(b_1021))

#create variable with complex value
c_1021 = 100 + 3j
print("The type of variable having value",c_1021,"is",type(c_1021))
# Out:
# The type of variable having value 100 is <class 'int'>
# The type of variable having value 10.2345 is <class 'float'>
# The type of variable having value (100+3j) is <class 'complex'>

# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# Penjelasan:
# 1. Deklarasi a_1021 dengan nilai 100 sebagai integer.
# 2. Cetak ("The type of variable having value",a_1021,"is",type(a_1021)) dengan type() digunakan untuk mengetahui tipe variabel dari a_1021.
# 3. Deklarasi b_1021 dengan nilai 10.2345 sebagai float.
# 4. Cetak ("The type of variable having value",b_1021,"is",type(b_1021)) dengan type() digunakan untuk mengetahui tipe variabel dari b_1021.
# 5. Deklarasi c_1021 dengan nilai (100 + 3j) sebagai komplek.
# 6. Cetak ("The type of variable having value",c_1021,"is",type(c_1021)) dengan type() digunakan untuk mengetahui tipe variabel dari c_1021
#
#
# ### 2.2.2 Program String_2611531021
# </div>

# %%
# Buat file dengan nama string String_2611531021.py
# nama variabel ditambah 4 digit terakhir contoh: nama_1021
# ganti programnya dan data masing2
nama_1021 = "Adib"
jenis_kelamin_1021 = 'L'
alamat_1021 = """
    Kampung Dalam, Pauh,
    Pasar Baru, Padang,
    Sumatera Barat, Indonesia
"""

agama_1021 = "Islam"
print("Nama saya adalah: ", nama_1021)
print("Jenis kelamin saya adalah: ", jenis_kelamin_1021)
print("Alamat saya adalah: ", alamat_1021)
print("Agama saya adalah: ", agama_1021)
# Out:
# Nama saya adalah:  Adib
# Jenis kelamin saya adalah:  L
# Alamat saya adalah:
#     Kampung Dalam, Pauh,
#     Pasar Baru, Padang,
#     Sumatera Barat, Indonesia
#
# Agama saya adalah:  Islam

# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# Penjelasan:
# 1. Deklarasi nama_1021 = "Adib" sebagai string
# 2. Deklarasi jenis_kelamin_1021 = 'L' sebagai string
# 3. Deklarasi alamat_1021 = """Kampung Dalam, Pauh, Pasar Baru, Padang, Sumatera Barat, Indonesia""" sebagai string
# 4. Deklarasi agama_1021 = "Islam" sebagai string
# 5. Cetak ("Nama saya adalah: ", nama_1021)
# 6. Cetak ("Jenis kelamin saya adalah: ", jenis_kelamin_1021)
# 7. Cetak ("Alamat saya adalah: ", alamat_1021)
# 8. Cetak ("Agama saya adalah: ", agama_1021)
# ### 2.2.3 Program Boolean_2611531021
# </div>

# %%
# Buat file dengan nama Boolean_2611531021
# Nama variabel ditambah 4 digit nim terakhir contoh: nilai_1234
# Deklarasi variabel dengan tipe data Boolean
is_lulus_1021 = True
is_cumlaude_1021 = True

# Menggunakan Boolean
nilai_1021 = 85
batas_lulus_1021 = 75

# Menantukan nilai Boolean dari kondisi
status_kelulusan_1021 = nilai_1021 >= batas_lulus_1021 # Hasilnya akan True

print("=== Check Kelulusan ===")
print("Nilai: ",nilai_1021)
print("Apakah lulus?: ",status_kelulusan_1021)
if is_lulus_1021 and is_cumlaude_1021:
    print("Selamat, Anda lulus dengan predikat Cum Laude!")
# Out:
# === Check Kelulusan ===
# Nilai:  85
# Apakah lulus?:  True
# Selamat, Anda lulus dengan predikat Cum Laude!

# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# Penjelasan:
# 1. Deklarasi is_lulus_1021 = True sebagai boolean
# 2. Deklarasi is_cumlaude_1021 = True sebagai boolean
# 3. Deklarasi nilai_1021 = 85 sebagai integer
# 5. Deklarasi batas_lulus_1021 = 75 sebagai integer
# 6. Deklarasi status_kelulusan_1021 = nilai_1021 >= batas_lulus_1021 sebagai boolean
# 7. Cetak ("=== Check Kelulusan ===")
# 8. Cetak ("Nilai: ",nilai_1021)
# 9. Cetak ("Apakah lulus?: ",status_kelulusan_1021)
# 10. Jika is_lulus_1021 dan is_cumlaude_1021 bernilai benar cetak ("Selamat, Anda lulus dengan predikat Cum Laude!")
#
# ### 2.2.4 Program Input_2611531021
# </div>

# %%
# Buat file dengan nama Input_261151021.py
# Buat Program untuk menghitung luas persegi panjang
# Nama variabel ditambah 4 digit mnimm terakhir contoh: nama_1021
# Program ini menggunakan fungsi input() untuk meminta pengguna
# memasukan nilai panjang dan lebar persegi panjang
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
panjang_1021 = input("Masukkan nilai panjang: ")
lebar_1021 = input("Masukkan nilai lebar: ")
luas_1021 = int(panjang_1021) * int(lebar_1021)
print("Luas = ",luas_1021)
# Out:
# Luas =  1575

# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# Penjelasan:
# 1. Input nilai panjang_1021
# 2. Input nilai lebar_1021
# 3. Nilai luas_1021 = int(panjang_1021) * int(lebar_1021)
# 4. Cetak ("Luas = ",luas_1021)
#
# ### 2.2.5 Program Konstanta_2611531021
# </div>

# %%
# Buat file dengan nama Konstanta_2611531021
# Program ini menggunakan konstanta untuk menghitun luas lingkaran
# nama variabel ditambah 4 digit nim terakhir contoh: jari_1021

from typing import Final
PI: Final = 3.14
print("Pi: %f" % (PI))
jari_1021 = float(input("Masukkan nilai jari-jari: "))
luas_1021 = PI * jari_1021
print("Luas lingkaran dengan jari-jari %.2f adalah %.2f" % (jari_1021,luas_1021))
# Out:
# Pi: 3.140000
# Luas lingkaran dengan jari-jari 20.00 adalah 62.80

# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# Penjelasan:
# 1. Pemanggilan Final dari library typing from typing import Final
# 2. Deklarasi PI: Final = 3.14 sebagai konstanta
# 3. Cetak ("Pi: %f" % (PI))
# 4. Nilai jari_1021 = float(input("Masukkan nilai jari-jari: "))
# 5. Nilai luas_1021 = PI * jari_1021
# 6. Cetak ("Luas lingkaran dengan jari-jari %.2f adalah %.2f" % (jari_1021,luas_1021))
#
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="image/soal_tugas.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>
#
# **Kode Jawaban :**
#
# a. Kode Program tugas2_2611531021
# </div>

# %%
print("=== SISTEM REGISTRASI PRAKTIKAN ALPRO 2026 ===")
nama_1021 = input("Masukkan Nama Mahasiswa : ")
kelamin_1021 = input("Masukkan Jenis Kelamin (L/P): ")
umur_1021 = int(input("Masukkan Umur : "))
skor_1021 = float(input("Masukkan Skor Tes Awal : "))

alamat_1021 = """
Kampung dalam,
Kecamatan Pauh,
Kota Padang,
Sumatera Barat,
Indonesia
"""
from typing import Final
kkm_1021: Final = 75.0
token_1021 = 100+3j
lulus_1021 = skor_1021 > kkm_1021

print("\n=== DATA PRAKTIKAN & HASIL PEMERIKSAAN ===")
print("Nama Mahasiswa : ",nama_1021," | ",type(nama_1021))
print("Jenis Kelamin : ",kelamin_1021," | ",type(kelamin_1021))
print("Alamat Domisili : ",alamat_1021," | ",type(alamat_1021))
print("Umur : ",umur_1021," tahun | ",type(umur_1021))
print("Skor Tes Awal : ",skor_1021," | ",type(skor_1021))
print("ID Token Sinyal: ",token_1021," | ",type(token_1021))

print("=== STATUS KELULUSAN PRAKTIKUM ===")
print("Batas Minimum Nilai: ",kkm_1021," | ",type(kkm_1021))
print("Apakah Dinyatakan Lulus?: ",lulus_1021," | ",type(lulus_1021))
# Out:
# === SISTEM REGISTRASI PRAKTIKAN ALPRO 2026 ===
#
# === DATA PRAKTIKAN & HASIL PEMERIKSAAN ===
# Nama Mahasiswa :  adib khairi muzakki e  |  <class 'str'>
# Jenis Kelamin :  L  |  <class 'str'>
# Alamat Domisili :
# Kampung dalam,
# Kecamatan Pauh,
# Kota Padang,
# Sumatera Barat,
# Indonesia
#   |  <class 'str'>
# Umur :  19  tahun |  <class 'int'>
# Skor Tes Awal :  100.0  |  <class 'float'>
# ID Token Sinyal:  (100+3j)  |  <class 'complex'>
# === STATUS KELULUSAN PRAKTIKUM ===
# Batas Minimum Nilai:  75.0  |  <class 'float'>
# Apakah Dinyatakan Lulus?:  True  |  <class 'bool'>

# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# **Penjelasan :**
# 1. Menampilkan judul program
# Program diawali dengan menampilkan judul Sistem Registrasi Praktikan ALPRO 2026 sebagai identitas dari program yang dibuat.
# 2. Memasukkan nama mahasiswa
# Program meminta pengguna memasukkan nama mahasiswa. Data yang dimasukkan disimpan sebagai string.
# 3. Memasukkan jenis kelamin
# Pengguna diminta memasukkan jenis kelamin dengan pilihan L atau P. Data tersebut juga disimpan dalam bentuk string.
# 4. Memasukkan umur
# Program meminta umur mahasiswa. Data yang dimasukkan diubah menjadi integer, karena umur merupakan bilangan bulat.
# 5. Memasukkan skor tes awal
# Pengguna memasukkan nilai tes awal. Nilai tersebut disimpan sebagai float agar dapat menerima angka desimal.
# 6. Menyimpan alamat domisili
# Program menyimpan alamat domisili dalam bentuk teks beberapa baris. Data tersebut termasuk tipe string.
# 7. Menentukan nilai KKM
# Nilai batas minimum ditetapkan sebesar 75.0 dan dibuat sebagai konstanta menggunakan Final, sehingga nilai tersebut dimaksudkan untuk tidak diubah selama program berjalan.
# 8. Membuat ID Token Sinyal
# Program menyimpan nilai 100 + 3j yang merupakan bilangan kompleks (complex). Angka 100 merupakan bagian real, sedangkan 3j merupakan bagian imajiner.
# 9. Menentukan status kelulusan
# Skor tes awal dibandingkan dengan nilai KKM. Jika skor lebih besar dari 75, mahasiswa dinyatakan lulus. Hasil perbandingan menghasilkan nilai Boolean, yaitu benar atau salah.
# 10. Menampilkan data praktikan
# Program menampilkan kembali seluruh data yang telah dimasukkan, seperti nama, jenis kelamin, alamat, umur, skor, dan ID token.
# 11. Menampilkan tipe data
# Setiap data ditampilkan bersama tipe datanya. Hal ini bertujuan untuk menunjukkan penerapan berbagai tipe data seperti string, integer, float, complex, dan Boolean.
# 12. Menampilkan hasil pemeriksaan kelulusan
# Pada bagian akhir, program menampilkan nilai KKM beserta status apakah praktikan dinyatakan lulus atau tidak berdasarkan skor tes awal.
# </div>

# %% [markdown]
# ---
# <div style="height:1123px;font-family: 'Times New Roman', Times, serif;font-size: 18px;">
# <h1 align="center">BAB III<br>KESIMPULAN</h1>
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa tipe data dan variabel merupakan konsep dasar yang penting dalam pemrograman Python. Tipe data digunakan untuk menentukan jenis nilai yang akan diproses, seperti int, float, complek, string, bool, konstanta serta penggunaan input, sedangkan variabel digunakan untuk menyimpan atau mereferensikan nilai tersebut. Dengan memahami penggunaan tipe data dan variabel, mahasiswa dapat membuat program sederhana untuk menyimpan, mengolah, dan menampilkan data dengan lebih tepat serta menjadi dasar untuk mempelajari konsep pemrograman Python yang lebih lanjut.
# </div>

# %% [markdown]
# ---
# <div style="height:1123px;font-family: 'Times New Roman', Times, serif;font-size: 18px;">
# <h1 align="center">DAFTAR PUSTAKA</h1>
#
# 1. Python Software Foundation. (2026). Built-in Types — Python 3.14.7 documentation.
# https://docs.python.org/3/library/stdtypes.html
#
# 2. Python Software Foundation. (2026). The Python Language Reference — Python 3.14.7 documentation.
# https://docs.python.org/3/reference/
#
# 3. Python Software Foundation. (2026). Built-in Functions — Python 3.14.7 documentation.
# https://docs.python.org/3/library/functions.html
#
# 4. Python Software Foundation. (2026). Tipe Data — Dokumentasi Python 3.14.7.
# https://docs.python.org/id/3/library/datatypes.html
# </div>
